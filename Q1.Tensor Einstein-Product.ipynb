# %%
import numpy as np

# %%
def EstnProduct4ord(A,B):
    C=np.zeros(A.shape[0]*A.shape[1]*B.shape[2]*B.shape[3]).reshape(A.shape[0],A.shape[1],B.shape[2],B.shape[3])
    for i in range(A.shape[0]):
        for j in range(A.shape[1]):
            for k in range(B.shape[2]):
                for l in range(B.shape[3]):
                    for m in range(A.shape[2]):
                        for n in range(A.shape[3]):
                            C[i,j,k,l]+=A[i,j,m,n]*B[m,n,k,l]
    return C

# %%
A=np.arange(360).reshape(4,5,3,6)
B=np.arange(216).reshape(3,6,2,6)
C=EstnProduct4ord(A,B)
C.shape
# Out:
# (4, 5, 2, 6)

# %%
C
# Out:
# array([[[[ 21420.,  21573.,  21726.,  21879.,  22032.,  22185.],
#          [ 22338.,  22491.,  22644.,  22797.,  22950.,  23103.]],
#
#         [[ 54468.,  54945.,  55422.,  55899.,  56376.,  56853.],
#          [ 57330.,  57807.,  58284.,  58761.,  59238.,  59715.]],
#
#         [[ 87516.,  88317.,  89118.,  89919.,  90720.,  91521.],
#          [ 92322.,  93123.,  93924.,  94725.,  95526.,  96327.]],
#
#         [[120564., 121689., 122814., 123939., 125064., 126189.],
#          [127314., 128439., 129564., 130689., 131814., 132939.]],
#
#         [[153612., 155061., 156510., 157959., 159408., 160857.],
#          [162306., 163755., 165204., 166653., 168102., 169551.]]],
#
#
#        [[[186660., 188433., 190206., 191979., 193752., 195525.],
#          [197298., 199071., 200844., 202617., 204390., 206163.]],
#
#         [[219708., 221805., 223902., 225999., 228096., 230193.],
#          [232290., 234387., 236484., 238581., 240678., 242775.]],
#
#         [[252756., 255177., 257598., 260019., 262440., 264861.],
#          [267282., 269703., 272124., 274545., 276966., 279387.]],
#
#         [[285804., 288549., 291294., 294039., 296784., 299529.],
#          [302274., 305019., 307764., 310509., 313254., 315999.]],
#
#         [[318852., 321921., 324990., 328059., 331128., 334197.],
#          [337266., 340335., 343404., 346473., 349542., 352611.]]],
#
#
#        [[[351900., 355293., 358686., 362079., 365472., 368865.],
#          [372258., 375651., 379044., 382437., 385830., 389223.]],
#
#         [[384948., 388665., 392382., 396099., 399816., 403533.],
#          [407250., 410967., 414684., 418401., 422118., 425835.]],
#
#         [[417996., 422037., 426078., 430119., 434160., 438201.],
#          [442242., 446283., 450324., 454365., 458406., 462447.]],
#
#         [[451044., 455409., 459774., 464139., 468504., 472869.],
#          [477234., 481599., 485964., 490329., 494694., 499059.]],
#
#         [[484092., 488781., 493470., 498159., 502848., 507537.],
#          [512226., 516915., 521604., 526293., 530982., 535671.]]],
#
#
#        [[[517140., 522153., 527166., 532179., 537192., 542205.],
#          [547218., 552231., 557244., 562257., 567270., 572283.]],
#
#         [[550188., 555525., 560862., 566199., 571536., 576873.],
#          [582210., 587547., 592884., 598221., 603558., 608895.]],
#
#         [[583236., 588897., 594558., 600219., 605880., 611541.],
#          [617202., 622863., 628524., 634185., 639846., 645507.]],
#
#         [[616284., 622269., 628254., 634239., 640224., 646209.],
#          [652194., 658179., 664164., 670149., 676134., 682119.]],
#
#         [[649332., 655641., 661950., 668259., 674568., 680877.],
#          [687186., 693495., 699804., 706113., 712422., 718731.]]]])
